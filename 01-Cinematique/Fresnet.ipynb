# %%
import numpy as np

from bokeh.io import push_notebook, show, output_notebook
from bokeh.plotting import figure
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
t=np.linspace(0.01,6,100)

# %%
x=t

# %% [markdown]
# On choisit une fonction de t: $$y(t)=0.3[2.1+\sin(t)+\sin(2t)]$$
# on calcule sa dérivée première et seconde

# %%
y=0.3*(np.sin(t)+2.1+np.sin(2*t))
yp=0.3*(np.cos(t)+2*np.cos(2*t))
ys=0.3*(-np.sin(t)-4*np.sin(2*t))

# %% [markdown]
# Le rayon de courbure au point $P$ est donné par
# $$R=\frac{(1+y'^2)^{3/2}}{y''}$$

# %%
R=(1+yp**2)**(3/2)/(ys)

# %%
p = figure(plot_height=360, plot_width=792, y_range=(-1,2.2), x_range=(0,6))
l=p.line(x,y)   
show(p)
# Out:
#   <div class="bk-root" id="ba401ec1-39d4-4d34-a5c2-117353166738" data-root-id="2653"></div>

# %%
from IPython.display import Image
Image("fresnet.png")
